# %%
import matplotlib.pyplot as plt
year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
gdp = [3079.9, 3250.1, 3398.8, 3574, 3678.2, 3721.8, 3744, 4003.6, 4165.5]
plt.plot(year, gdp)

# %%
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt
year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
gdp = [3079.9, 3250.1, 3398.8, 3574, 3678.2, 3721.8, 3744, 4003.6, 4165.5]
plt.figure(figsize=(5,3))
plt.plot(year, gdp, color='#008080', marker='h', linestyle='--')
plt.title('GDP per capital')
plt.xlabel('years')
plt.ylabel('ten thousand won')
plt.ylim(2500, 4500)
plt.show()

# %%
year = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
seoul = [12.1,12,12.2,12.5,13.4,13.6,13.6,13,12.9,13.5,13.2,13.7,13.2]
jeju = [15.6,15.6,15.7,16.5,16.2,16.7,17,16.8,16.6,16.8,16.7,17.5,17]

import matplotlib.pyplot as plt
plt.plot(year, seoul)
plt.plot(year, jeju)
plt.show()

# %%
year = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
seoul = [12.1,12,12.2,12.5,13.4,13.6,13.6,13,12.9,13.5,13.2,13.7,13.2]
jeju = [15.6,15.6,15.7,16.5,16.2,16.7,17,16.8,16.6,16.8,16.7,17.5,17]

import matplotlib.pyplot as plt
plt.figure(figsize = (5,3))
plt.plot(year, seoul, label = 'seoul')
plt.plot(year, jeju, label = 'jeju')
plt.ylim(10,20)
plt.title('temperature')
plt.xlabel('year')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

season = ['spring', 'summer', 'autumn', 'winter']
precipitation = [330.5, 612.8, 256.4, 13.3]

plt.figure(figsize = (5,3))
plt.bar(season, precipitation)
plt.title('precipitation')
plt.ylabel('m')
plt.show()

# %%
import matplotlib.pyplot as plt

preci = {'spring' : 330.5, 'summer' : 612.8, 'autumn' : 256.4, 'winter' : 13.3}


plt.figure(figsize = (5,3))
plt.bar(preci.keys(), preci.values())
plt.title('precipitation')
plt.ylabel('mm')
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2000, 2005, 2010, 2015, 2020]
single_person = [15.5, 20.0, 23.9, 27.2, 31.7]
baby_born = [640089, 438707, 470171, 438420, 272337]

plt.figure(figsize = (5,3))
plt.scatter(single_person, baby_born)
plt.xlabel('single person household ratio')
plt.ylabel('the number od babies born')
plt.show()

# %%
import matplotlib.pyplot as plt

height = [156.9, 159.9, 153.5, 151.2, 154.6, 168.3, 165, 154.7, 146, 152.4]
wieght = [48.7, 58.5, 48.4, 39, 58.9, 80.8, 59.3, 49.4, 35.3, 51.8]
gender = ['f', 'f', 'f', 'f', 'f', 'm', 'm', 'm', 'm', 'm']

plt.figure(figsize = (5,3))
plt.scatter(height, wieght)
plt.xlabel('height')
plt.ylabel('wieght')
plt.show()

# %%
import matplotlib.pyplot as plt

height = [156.9, 159.9, 153.5, 151.2, 154.6, 168.3, 165, 154.7, 146, 152.4]
wieght = [48.7, 58.5, 48.4, 39, 58.9, 80.8, 59.3, 49.4, 35.3, 51.8]
gender = ['f', 'f', 'f', 'f', 'f', 'm', 'm', 'm', 'm', 'm']
colors = ['r' if a == 'f' else 'b' for a in gender]

plt.figure(figsize = (5,3))
plt.scatter(height, wieght, c=colors)
plt.xlabel('height')
plt.ylabel('wieght')
plt.show()

# %%
from IPython.utils import text
import matplotlib.pyplot as plt

name = ['Jessica', 'Liam',  'Sophia']
x = [75, 92, 83]
y = [79, 89, 90]

plt.figure(figsize = (5, 3))
plt.scatter(x, y)
plt.annotate(name[0], (x[0], y[0]), xytext = (5, -10), textcoords = 'offset points')
plt.annotate(name[1], (x[1], y[1]), xytext = (5, -10), textcoords = 'offset points')
plt.annotate(name[2], (x[2], y[2]), xytext = (5, -10), textcoords = 'offset points')
plt.xlim(73, 95)
plt.ylim(75, 93)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import matplotlib.pyplot as plt

blood = {'A':0,'B':0,'O':0,'AB':0}

while True:
  s = input('혈액형(A, B, O, AB) 또는 종료: ')
  if s=='종료':
    break
  elif s in blood:
    blood[s] += 1
  else:
    print('잘못 입력했습니다.')

plt.figure(figsize=(5,3))
plt.bar(blood.keys(), blood.values(), width=0.6)
plt.xlabel('blood type')
plt.ylabel('frequency')
plt.show()
# Out:
# 혈액형(A, B, O, AB) 또는 종료: A
# 혈액형(A, B, O, AB) 또는 종료: A
# 혈액형(A, B, O, AB) 또는 종료: B
# 혈액형(A, B, O, AB) 또는 종료: O
# 혈액형(A, B, O, AB) 또는 종료: 종료

# %%
import matplotlib.pyplot as plt

import random

x = [random.normalvariate(0,1) for _ in range(1000)]

plt.figure(figsize=(5,3))
plt.hist(x, bins=20, alpha=0.5)
plt.ylabel('frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

cat = plt.imread('/content/cat.3.jpg')
plt.imshow(cat)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5368/3055413713.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 cat = plt.imread('/content/cat.3.jpg')
#       4 plt.imshow(cat)
#       5 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2611         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2612 ) -> np.ndarray:
# -> 2613     return matplotlib.image.imread(fname, format)
#    2614
#    2615
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in imread(fname, format)
#    1500             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501             )
# -> 1502     with img_open(fname) as image:
#    1503         return (_pil_png_to_float_array(image)
#    1504                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/cat.3.jpg'

# %%
plt.figure(figsize=(3,3))
plt.imshow(cat)
plt.axis('off')
plt.savefig('result.png')
plt.show()

# %%
cat = plt.imread('/content/cat.3.jpg')
dog = plt.imread('/content/dog.384.jpg')

plt.figure(figsize=(5,3))

plt.subplot(1, 2, 1)
plt.imshow(cat)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(dog)
plt.axis('off')

plt.show()

# %%
cat = plt.imread('/content/cat.3.jpg')
dog = plt.imread('/content/dog.384.jpg')
imgs = [cat, dog]

plt.figure(figsize=(5,3))
for i in range(len(imgs)):
  plt.subplot(1, 2, i+1)
  plt.imshow(imgs[i])
  plt.axis('off')
plt.show()

# %%
cat = plt.imread('/content/cat.3.jpg')
dog = plt.imread('/content/dog.384.jpg')
imgs = [cat, dog]
labels = ['cat', 'dog']

plt.figure(figsize=(5,3))
for i in range(len(imgs)):
  plt.subplot(1, 2, i+1)
  plt.imshow(imgs[i])
  plt.xticks([])
  plt.yticks([])
  plt.xlabel(labels[i])
plt.show()

# %%
import os

imgs = os.listdir('dog')

plt.figure(figsize=(5,5))
for i in range(len(imgs)):
  plt.subplot(2,2,i+1)
  img = plt.imread(os.path.join('dog', imgs[i]))
  plt.imshow(img)
  plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import random

dice1 = plt.imread('dice1.png')
dice2 = plt.imread('dice2.png')
dice3 = plt.imread('dice3.png')
dice4 = plt.imread('dice4.png')
dice5 = plt.imread('dice5.png')
dice6 = plt.imread('dice6.png')
dices = [dice1,dice2,dice3,dice4,dice5,dice6]

plt.figure(figsize=(4.5,2))
for i in range(2):
  plt.subplot(1, 2, i+1)
  select = random.randint(0,len(dices)-1)
  plt.imshow(dices[select])
  plt.axis('off')
  plt.show()

# %%
import matplotlib.pyplot as plt
import os

imgs = os.listdir('catdog')

plt.figure(figsize=(5,5))
for i in range(len(imgs)):
  plt.subplot(3,3,i+1)
  img = plt.imread(os.path.join('catdog', imgs[i]))
  plt.imshow(img)
  plt.axis('off')

plt.show()

# %%
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 3 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (49.5 MB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 118251 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

course = {'TOEIC' : 0, 'TOEFL' : 0, 'TOEIC SPEAKING' : 0, 'OPIC' : 0, 'IELTS' : 0}

print('수강하고 싶은 강좌를 입력하시오. 단 여러개라면 콤마로 구분하시오. 종료할려면 종료를 치시오.')

while True :
  s = input('강좌 : ')
  if s == '종료' :
    break

  for a in s.split(','):
    if a in course :
      course[a] += 1
    else :
      print(f'{a}는 등록되지 않은 강좌입니다.')

plt.bar(course.keys(), course.values(), width = 0.5)
plt.title('수강하고 싶은 강좌 조사')
plt.xlabel('수강하고 싶은 과목')
plt.ylabel('비율')
plt.show()
# Out:
# 수강하고 싶은 강좌를 입력하시오. 단 여러개라면 콤마로 구분하시오. 종료할려면 종료를 치시오.
# 강좌 :
# 는 등록되지 않은 강좌입니다.
# 강좌 : 종료
